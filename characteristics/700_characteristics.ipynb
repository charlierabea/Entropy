# %%
import os
import numpy as np
import pandas as pd
from skimage import io
import util2
import cv2
import tortuosity


parent_dir = r"/home/charlie/projects/entropy/input/"


# Create dictionaries to store the results
#active_stats: list[tuple[tuple, float]]
#inactive_stats: list[tuple[tuple, float]]

faz_area = {}
faz_circularity = {}
vessel_density = {}
vessel_length_density = {}


#第一層 列出前處理方式種類
for dirname in os.listdir(parent_dir):
    if (dirname.endswith(".DS_Store")):
        pass
    
    #each image has up to two parameters, use 'parameter' list to store them
    parameter = []
    
    #each image has up to two parameters, use four lists to store the metrics
    reactive_active1 = []
    reactive_inactive1 = []
    treatment_active1 = []
    treatment_inactive1 = []
    
    reactive_active2 = []
    reactive_inactive2 = []
    treatment_active2 = []
    treatment_inactive2 = []
       
    type_dir = parent_dir + dirname+'/'
    print(type_dir)
    
    #第二層 列出前處理方式
    for dirname1 in os.listdir(type_dir):
        if (dirname1.endswith(".DS_Store")):
            continue
        
        pre_dir = type_dir + dirname1+'/'
        print(pre_dir)
        
        #第三層 列出reactive/treatment
        for dirname2 in os.listdir(pre_dir):
            if (dirname2.endswith(".DS_Store")):
                continue
            
            cond_dir = pre_dir + dirname2+'/'
            print(cond_dir)
            
            #第四層 列出active/inactive
            for dirname3 in os.listdir(cond_dir):
                if (dirname3.endswith(".DS_Store")):
                    continue
                    
                amd_dir = cond_dir + dirname3+'/'
                print(amd_dir)

                #列出目錄中的所有圖像
                for filename in os.listdir(amd_dir):
                    if not (filename.endswith(".bmp") or filename.endswith(".jpg")):
                        continue
                        
                    # 組合文件路徑
                    filepath = os.path.join(amd_dir, filename)
                    image = cv2.imread(filepath)
                    #print(filepath)
                    
                    #column名稱
                    column_name = dirname1+ '_'+ dirname2 + '_' + dirname3
                        
                    #initialize the parameters
                    img_parameter_1 = 0
                    img_parameter_2 = 0
                    image_name = filename.split('_')
                    
                    #分類：binary，parameter為entropy和VD
                    # if(dirname == 'binary' or 'findlarge' or 'raw'):
                    #     # Read the image and calculate the entropy
                    #     img_parameter_1 = util2.calculate_image_entropy(filepath)
                    #     # Calculate the blood vessel density
                    #     img_parameter_2 = util2.calculate_bvd(image)
                    #     if(len(parameter)<3):
                    #         parameter.append("entropy")
                    #         parameter.append('vd')
                    
                    # if(dirname == 'binary2'):
                    #     # calculate the blood vessel tortuosity
                    #     img_parameter_1 = util2.calculate_bvc(image)
                    #     # calculate the blood vessel fractal dimension
                    #     img_parameter_2 = img_parameter_1
                        
                    #     if(len(parameter)<3):
                    #         parameter.append("caliber")
                    #         parameter.append('caliber')
                    
                    if(dirname == 'skeletonize'):
                        print(image.shape)
                        # calculate the blood vessel tortuosity
                        img_parameter_1 = tortuosity.calculate_bvt_from_image(image, 128)
                        # calculate the fractal dimension
                        img_parameter_2 = img_parameter_1
                        if(len(parameter)<3):
                            parameter.append("tortuosity")
                            parameter.append('tortuosity')
                            
                    # if(dirname == 'raw' or 'findlarge'):
                    #     # Read the image and calculate the entropy
                    #     img_parameter_1 = util2.calculate_image_entropy(filepath)
                    #     img_parameter_2 = util2.calculate_image_entropy(filepath)
                    #     if(len(parameter)<3):                         
                    #         parameter.append("entropy")
                    #         parameter.append('entropy')   
                    
                    
                    
                    
                    """not done"""
                    
                            
                    # Add the results to the dictionary
                    #entropy[(column_name, image_name[0], image.shape[0], image.shape[1])] = img_entropy
                    if dirname2 == 'reactive':
                        if dirname3 == 'active':
                            reactive_active1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            reactive_active2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                        if dirname3 == 'inactive':
                            reactive_inactive1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1)) 
                            reactive_inactive2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                            
                    if dirname2 == 'treatment':
                        if dirname3 == 'active':
                            treatment_active1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            treatment_active2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                        if dirname3 == 'inactive':
                            treatment_inactive1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            treatment_inactive2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                            
    # After reading all data, sort them by patient_number
    #先用方法分再用數字分
    n=0
    print(treatment_inactive2)
    for a, b, c, d in ((reactive_active1, reactive_inactive1, treatment_active1, treatment_inactive1),(reactive_active2, reactive_inactive2, treatment_active2, treatment_inactive2)):
        for k in a,b,c,d:
            k.sort(key = lambda x: x[0][3])
            k.sort(key = lambda x: int(x[0][0]))

        dict_name_reactive = {}
        dict_name_treatment = {}
        
        #pair the active and inactive keys
        for (active_key, active_value), (inactive_key, inactive_value) in zip(a, b):
            pass
            dict_name_reactive[(inactive_key[0], inactive_key[3], active_key[0], active_key[3])] = [inactive_value, active_value]
        
        for (active_key, active_value), (inactive_key, inactive_value) in zip(c, d):
            pass
            dict_name_treatment[(inactive_key[0], inactive_key[3], active_key[0], active_key[3])] = [inactive_value, active_value]
            
        print(dict_name_reactive)
        #print(dict_name_reactive)
            
        # Convert the results dictionary to a DataFrame with a multi-level index
        df_reactive = pd.DataFrame.from_dict(dict_name_reactive, orient='index')
        df_reactive.index = pd.MultiIndex.from_tuples(df_reactive.index, names=['inactive_number', 'inactive_process', 'active_number', 'active_process'])
        df_treatment = pd.DataFrame.from_dict(dict_name_treatment, orient='index')
        df_treatment.index = pd.MultiIndex.from_tuples(df_treatment.index, names=['inactive_number', 'inactive_process', 'active_number', 'active_process'])
        
        # Pivot the DataFrame to have directory names as columns
        df_reactive_inactive = df_reactive.pivot_table(values=0, index=['active_number','inactive_number'], columns=['inactive_process'])
        df_reactive_active = df_reactive.pivot_table(values=1, index=['active_number','inactive_number'], columns=['active_process'])
        df_treatment_inactive = df_treatment.pivot_table(values=0, index=['active_number','inactive_number'], columns=['inactive_process'])
        df_treatment_active = df_treatment.pivot_table(values=1, index=['active_number','inactive_number'], columns=['active_process'])
        
        # combine the two data frames using concat
        combined_df1 = pd.concat([df_reactive_inactive, df_reactive_active], axis = 1, ignore_index=False)
        combined_df2 = pd.concat([df_treatment_inactive, df_treatment_active], axis = 1, ignore_index=False)
        
        # Save the results to an Excel file
        excel_name1 = dirname + '_' + parameter[n] + '_reactive'
        excel_name2 = dirname + '_' + parameter[n] + '_treatment'
        combined_df1.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name1+ '.xlsx')
        combined_df2.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name2+ '.xlsx')
        
        #計次   
        n+=1
# Out:
# /home/charlie/projects/entropy/input/binary/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/active/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/active/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/otsu/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/active/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/active/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/mean/
# /home/charlie/projects/entropy/input/binary/mean/treatment/
# /home/charlie/projects/entropy/input/binary/mean/treatment/active/
# /home/charlie/projects/entropy/input/binary/mean/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/mean/reactive/
# /home/charlie/projects/entropy/input/binary/mean/reactive/active/
# /home/charlie/projects/entropy/input/binary/mean/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/active/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/active/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/inactive/
# [(('1146', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('164', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('985', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1329', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('562', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1213', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1056', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1129', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('112', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('408', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('712', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('902', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('213', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('306', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1016', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('676', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1194', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('548', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1457', 337, 337, 'gabor_otsu_treatment_inactive'), 0), (('958', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('968', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('227', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('850', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('942', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('860', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('74', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('633', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1220', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('272', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('863', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('758', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('297', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('108', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('176', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('988', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1101', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('788', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1185', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('330', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1105', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('982', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('510', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1470', 337, 337, 'gabor_otsu_treatment_inactive'), 0), (('1336', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('95', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('821', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('932', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('254', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('82', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('775', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('58', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1333', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('650', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1483', 337, 337, 'gabor_otsu_treatment_inactive'), 0), (('1372', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1064', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1207', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('499', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('257', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('156', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('906', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('244', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('304', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('744', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('592', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1052', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('644', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('520', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('317', 741, 741, 'gabor_otsu_treatment_inactive'), 0), (('1095', 741, 741, 'gabor_otsu_treatment_inactive ...
# {('5', 'gabor_mean_reactive_inactive', '6', 'gabor_mean_reactive_active'): [0, 0], ('5', 'gabor_otsu_reactive_inactive', '6', 'gabor_otsu_reactive_active'): [0, 0], ('5', 'mean_reactive_inactive', '6', 'mean_reactive_active'): [0, 0], ('5', 'otsu_reactive_inactive', '6', 'otsu_reactive_active'): [0, 0], ('34', 'gabor_mean_reactive_inactive', '35', 'gabor_mean_reactive_active'): [0, 0], ('34', 'gabor_otsu_reactive_inactive', '35', 'gabor_otsu_reactive_active'): [0, 0], ('34', 'mean_reactive_inactive', '35', 'mean_reactive_active'): [0, 0], ('34', 'otsu_reactive_inactive', '35', 'otsu_reactive_active'): [0, 0], ('80', 'gabor_mean_reactive_inactive', '81', 'gabor_mean_reactive_active'): [0, 0], ('80', 'gabor_otsu_reactive_inactive', '81', 'gabor_otsu_reactive_active'): [0, 0], ('80', 'mean_reactive_inactive', '81', 'mean_reactive_active'): [0, 0], ('80', 'otsu_reactive_inactive', '81', 'otsu_reactive_active'): [0, 0], ('90', 'gabor_mean_reactive_inactive', '91', 'gabor_mean_reactive_active'): [0, 0], ('90', 'gabor_otsu_reactive_inactive', '91', 'gabor_otsu_reactive_active'): [0, 0], ('90', 'mean_reactive_inactive', '91', 'mean_reactive_active'): [0, 0], ('90', 'otsu_reactive_inactive', '91', 'otsu_reactive_active'): [0, 0], ('95', 'gabor_mean_reactive_inactive', '97', 'gabor_mean_reactive_active'): [0, 0], ('95', 'gabor_otsu_reactive_inactive', '97', 'gabor_otsu_reactive_active'): [0, 0], ('95', 'mean_reactive_inactive', '97', 'mean_reactive_active'): [0, 0], ('95', 'otsu_reactive_inactive', '97', 'otsu_reactive_active'): [0, 0], ('100', 'gabor_mean_reactive_inactive', '102', 'gabor_mean_reactive_active'): [0, 0], ('100', 'gabor_otsu_reactive_inactive', '102', 'gabor_otsu_reactive_active'): [0, 0], ('100', 'mean_reactive_inactive', '102', 'mean_reactive_active'): [0, 0], ('100', 'otsu_reactive_inactive', '102', 'otsu_reactive_active'): [0, 0], ('101', 'gabor_mean_reactive_inactive', '104', 'gabor_mean_reactive_active'): [0, 0], ('101', 'gabor_otsu_reactive_inactive', '104', 'gabor_otsu_reactive_active'): [0, 0], ('101', 'mean_reactive_inactive', '104', 'mean_reactive_active'): [0, 0], ('101', 'otsu_reactive_inactive', '104', 'otsu_reactive_active'): [0, 0], ('107', 'gabor_mean_reactive_inactive', '110', 'gabor_mean_reactive_active'): [0, 0], ('107', 'gabor_otsu_reactive_inactive', '110', 'gabor_otsu_reactive_active'): [0, 0], ('107', 'mean_reactive_inactive', '110', 'mean_reactive_active'): [0, 0], ('107', 'otsu_reactive_inactive', '110', 'otsu_reactive_active'): [0, 0], ('109', 'gabor_mean_reactive_inactive', '111', 'gabor_mean_reactive_active'): [0, 0], ('109', 'gabor_otsu_reactive_inactive', '111', 'gabor_otsu_reactive_active'): [0, 0], ('109', 'mean_reactive_inactive', '111', 'mean_reactive_active'): [0, 0], ('109', 'otsu_reactive_inactive', '111', 'otsu_reactive_active'): [0, 0], ('112', 'gabor_mean_reactive_inactive', '113', 'gabor_mean_reactive_active'): [0, 0], ('112', 'gabor_otsu_reactive_inactive', '113', 'gabor_otsu_reactive_active'): [0, 0], ('112', 'mean_reactive_inactive', '113', 'mean_reactive_active'): [0, 0], ('112', 'otsu_reactive_inactive', '113', 'otsu_reactive_active'): [0, 0], ('134', 'gabor_mean_reactive_inactive', '135', 'gabor_mean_reactive_active'): [0, 0], ('134', 'gabor_otsu_reactive_inactive', '135', 'gabor_otsu_reactive_active'): [0, 0], ('134', 'mean_reactive_inactive', '135', 'mean_reactive_active'): [0, 0], ('134', 'otsu_reactive_inactive', '135', 'otsu_reactive_active'): [0, 0], ('157', 'gabor_mean_reactive_inactive', '158', 'gabor_mean_reactive_active'): [0, 0], ('157', 'gabor_otsu_reactive_inactive', '158', 'gabor_otsu_reactive_active'): [0, 0], ('157', 'mean_reactive_inactive', '158', 'mean_reactive_active'): [0, 0], ('157', 'otsu_reactive_inactive', '158', 'otsu_reactive_active'): [0, 0], ('206', 'gabor_mean_reactive_inactive', '207', 'gabor_mean_reactive_active'): [0, 0], ('206', 'gabor_otsu_reactive_inactive', '207', 'gabor_otsu_reactive_active'): [0, 0], ('206', 'mean_reactive_inactive', ' ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_176508/565872480.py in <module>
#     188
#     189         # Save the results to an Excel file
# --> 190         excel_name1 = dirname + '_' + parameter[n] + '_reactive'
#     191         excel_name2 = dirname + '_' + parameter[n] + '_treatment'
#     192         combined_df1.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name1+ '.xlsx')
#
# IndexError: list index out of range

# %%
n=0
print(reactive_active2)
for a, b, c, d in ((reactive_active1, reactive_inactive1, treatment_active1, treatment_inactive1),(reactive_active2, reactive_inactive2, treatment_active2, treatment_inactive2)):
    for k in a,b,c,d:
        k.sort(key = lambda x: x[0][3])
        k.sort(key = lambda x: int(x[0][0]))

    dict_name_reactive = {}
    dict_name_treatment = {}
        
    #pair the active and inactive keys
    for (active_key, active_value), (inactive_key, inactive_value) in zip(a, b):
        pass
        dict_name_reactive[(inactive_key[0], inactive_key[3], active_key[0], active_key[3])] = [inactive_value, active_value]
    
    for (active_key, active_value), (inactive_key, inactive_value) in zip(c, d):
        pass
        dict_name_treatment[(active_key[0], active_key[3], inactive_key[0], inactive_key[3])] = [active_value, inactive_value]
        
    
    
    # Convert the results dictionary to a DataFrame with a multi-level index
    df_reactive = pd.DataFrame.from_dict(dict_name_reactive, orient='index')
    df_reactive.index = pd.MultiIndex.from_tuples(df_reactive.index, names=['inactive_number', 'inactive_process', 'active_number', 'active_process'])
    df_treatment = pd.DataFrame.from_dict(dict_name_treatment, orient='index')
    df_treatment.index = pd.MultiIndex.from_tuples(df_treatment.index, names=['active_number', 'active_process', 'inactive_number', 'inactive_process'])
    
    # Pivot the DataFrame to have directory names as columns
    df_reactive_inactive = df_reactive.pivot_table(values=0, index=['active_number','inactive_number'], columns=['inactive_process'])
    df_reactive_active = df_reactive.pivot_table(values=1, index=['active_number','inactive_number'], columns=['active_process'])
    df_treatment_active = df_treatment.pivot_table(values=0, index=['active_number','inactive_number'], columns=['active_process'])
    df_treatment_inactive = df_treatment.pivot_table(values=1, index=['active_number','inactive_number'], columns=['inactive_process'])
    
    # combine the two data frames using concat
    combined_df1 = pd.concat([df_reactive_inactive, df_reactive_active], axis = 1, ignore_index=False)
    combined_df2 = pd.concat([df_treatment_inactive, df_treatment_active], axis = 1, ignore_index=False)
    
    # Save the results to an Excel file
    excel_name1 = dirname + '_' + parameter[n] + '_reactive'
    excel_name2 = dirname + '_' + parameter[n] + '_treatment'
   
    # combined_df1.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name1+ '.xlsx')
    # combined_df2.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name2+ '.xlsx')
    
    #計次   
    n+=1
# Out:
# [(('6', 741, 741, 'gabor_mean_reactive_active'), nan), (('6', 741, 741, 'gabor_otsu_reactive_active'), nan), (('6', 741, 741, 'mean_reactive_active'), nan), (('6', 741, 741, 'otsu_reactive_active'), nan), (('35', 741, 741, 'gabor_mean_reactive_active'), nan), (('35', 741, 741, 'gabor_otsu_reactive_active'), nan), (('35', 741, 741, 'mean_reactive_active'), nan), (('35', 741, 741, 'otsu_reactive_active'), nan), (('81', 741, 741, 'gabor_mean_reactive_active'), nan), (('81', 741, 741, 'gabor_otsu_reactive_active'), nan), (('81', 741, 741, 'mean_reactive_active'), nan), (('81', 741, 741, 'otsu_reactive_active'), nan), (('91', 741, 741, 'gabor_mean_reactive_active'), nan), (('91', 741, 741, 'gabor_otsu_reactive_active'), nan), (('91', 741, 741, 'mean_reactive_active'), nan), (('91', 741, 741, 'otsu_reactive_active'), nan), (('97', 741, 741, 'gabor_mean_reactive_active'), nan), (('97', 741, 741, 'gabor_otsu_reactive_active'), nan), (('97', 741, 741, 'mean_reactive_active'), nan), (('97', 741, 741, 'otsu_reactive_active'), nan), (('102', 741, 741, 'gabor_mean_reactive_active'), nan), (('102', 741, 741, 'gabor_otsu_reactive_active'), nan), (('102', 741, 741, 'mean_reactive_active'), nan), (('102', 741, 741, 'otsu_reactive_active'), nan), (('104', 741, 741, 'gabor_mean_reactive_active'), nan), (('104', 741, 741, 'gabor_otsu_reactive_active'), nan), (('104', 741, 741, 'mean_reactive_active'), nan), (('104', 741, 741, 'otsu_reactive_active'), nan), (('110', 741, 741, 'gabor_mean_reactive_active'), nan), (('110', 741, 741, 'gabor_otsu_reactive_active'), nan), (('110', 741, 741, 'mean_reactive_active'), nan), (('110', 741, 741, 'otsu_reactive_active'), nan), (('111', 741, 741, 'gabor_mean_reactive_active'), nan), (('111', 741, 741, 'gabor_otsu_reactive_active'), nan), (('111', 741, 741, 'mean_reactive_active'), nan), (('111', 741, 741, 'otsu_reactive_active'), nan), (('113', 741, 741, 'gabor_mean_reactive_active'), nan), (('113', 741, 741, 'gabor_otsu_reactive_active'), nan), (('113', 741, 741, 'mean_reactive_active'), nan), (('113', 741, 741, 'otsu_reactive_active'), nan), (('135', 741, 741, 'gabor_mean_reactive_active'), nan), (('135', 741, 741, 'gabor_otsu_reactive_active'), nan), (('135', 741, 741, 'mean_reactive_active'), nan), (('135', 741, 741, 'otsu_reactive_active'), nan), (('158', 741, 741, 'gabor_mean_reactive_active'), nan), (('158', 741, 741, 'gabor_otsu_reactive_active'), nan), (('158', 741, 741, 'mean_reactive_active'), nan), (('158', 741, 741, 'otsu_reactive_active'), nan), (('207', 741, 741, 'gabor_mean_reactive_active'), nan), (('207', 741, 741, 'gabor_otsu_reactive_active'), nan), (('207', 741, 741, 'mean_reactive_active'), nan), (('207', 741, 741, 'otsu_reactive_active'), nan), (('253', 741, 741, 'gabor_mean_reactive_active'), nan), (('253', 741, 741, 'gabor_otsu_reactive_active'), nan), (('253', 741, 741, 'mean_reactive_active'), nan), (('253', 741, 741, 'otsu_reactive_active'), nan), (('287', 741, 741, 'gabor_mean_reactive_active'), nan), (('287', 741, 741, 'gabor_otsu_reactive_active'), nan), (('287', 741, 741, 'mean_reactive_active'), nan), (('287', 741, 741, 'otsu_reactive_active'), nan), (('295', 741, 741, 'gabor_mean_reactive_active'), nan), (('295', 741, 741, 'gabor_otsu_reactive_active'), nan), (('295', 741, 741, 'mean_reactive_active'), nan), (('295', 741, 741, 'otsu_reactive_active'), nan), (('305', 741, 741, 'gabor_mean_reactive_active'), nan), (('305', 741, 741, 'gabor_otsu_reactive_active'), nan), (('305', 741, 741, 'mean_reactive_active'), nan), (('305', 741, 741, 'otsu_reactive_active'), nan), (('310', 741, 741, 'gabor_mean_reactive_active'), nan), (('310', 741, 741, 'gabor_otsu_reactive_active'), nan), (('310', 741, 741, 'mean_reactive_active'), nan), (('310', 741, 741, 'otsu_reactive_active'), nan), (('410', 712, 711, 'gabor_mean_reactive_active'), nan), (('410', 712, 711, 'gabor_otsu_reactive_active'), nan), (('410', 712, 711, 'mean_reactive_active'), nan), (('410', 712, 711, 'otsu_reactive_active'), n ...

# %%
import numpy as np
import cv2
from skimage.measure import regionprops, label
#from scipy.spatial import distance

path ='/home/charlie/projects/entropy/input/faz/faz/reactive/active/6_1054482-8_20170926_OCT_00000256.bmp_superficial.jpg'

faz_image = cv2.imread('/home/charlie/projects/entropy/input/faz/faz/reactive/active/6_1054482-8_20170926_OCT_00000256.bmp_superficial.jpg', cv2.COLOR_BGR2GRAY)

#faz_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Label the binary FAZ image and extract the properties of each connected component
labeled_image = label(faz_image)
regions = regionprops(labeled_image)
# Find the largest connected component (i.e., the FAZ)
faz_region = max(regions, key=lambda r: r.area)
# Calculate the perimeter of the FAZ
faz_perimeter = faz_region.perimeter
# Calculate the radius of a reference circle with area identical to the FAZ
faz_area = faz_region.filled_area
faz_radius = np.sqrt(faz_area / np.pi)
# Calculate the perimeter of the reference circle
reference_perimeter = 2 * np.pi * faz_radius
# Calculate the FAZ-CI as the ratio of the FAZ perimeter to the reference circle perimeter
faz_ci = faz_perimeter / reference_perimeter
print(faz_area, faz_ci)
# Out:
# 39460 4.0334067952621675
