# %%
import cv2
import pytesseract
from os import listdir
from os.path import isfile, isdir, join
import pandas as pd
import numpy as np
import skimage.measure    
from matplotlib import pyplot as plt
from PIL import Image

# %%
def entropy(signal):
        '''
        function returns entropy of a signal
        signal must be a 1-D numpy array
        '''
        lensig=signal.size
        symset=list(set(signal))
        numsym=len(symset)
        propab=[np.size(signal[signal==i])/(1.0*lensig) for i in symset]
        ent=np.sum([p*np.log2(1.0/p) for p in propab])
        return ent

# %%
clahe = cv2.createCLAHE()

# %%
mypath = "/Users/charliethebear/Documents/Lab/Entropy/Raw_superficial/Reactive/inactive"
mypath2 = "/Users/charliethebear/Documents/Lab/Entropy/Raw_superficial/Reactive/active"
files = listdir(mypath)
files2 = listdir(mypath2)

#建立要寫入excel的資料
write = pd.DataFrame({'inactive':[],
                  'active':[], 'inactive_entropy':[], 'active_entropy':[]})
writeclahe= pd.DataFrame({, 'equalized_inactive_entropy':[], 'equalized_active_entropy':[],
                          'clahe_inactive_entropy':[], 'clahe_active_entropy':[]})
print(write)
# Out:
#   File "<ipython-input-97-8f7604babd25>", line 9
#     writeclahe= pd.DataFrame({, 'equalized_inactive_entropy':[], 'equalized_active_entropy':[],
#                               ^
# SyntaxError: invalid syntax

# %%
#圖片直接拿去算entropy
num=0
#inactive
for f in files:
    #取得檔案路徑/病患編號
    if f[-3:]=="jpg":
        fullpath = join(mypath, f)
        number= f.split("_")[0]
        #print(number)
    
        colorIm=Image.open(fullpath)
        greyIm=colorIm.convert('L')
        colorIm=np.array(colorIm)
        greyIm=np.array(greyIm)
        fullimg= greyIm[0:-1, 0:-1].flatten()
        ent= entropy(fullimg)
        
        write = write.append({
            "inactive": number,
            "inactive_entropy": ent
        }, ignore_index=True)
    
    
    
#active
for f in files2:
    if f[-3:]=="jpg":
        fullpath = join(mypath2, f)
        number= f.split("_")[0]
        #print(number)
    
        colorIm=Image.open(fullpath)
        greyIm=colorIm.convert('L')
        colorIm=np.array(colorIm)
        greyIm=np.array(greyIm)
        fullimg= greyIm[0:-1, 0:-1].flatten()
        ent= entropy(fullimg)
    
        write = write.append({
            "active": number,
            "active_entropy": ent
        }, ignore_index=True)
    
    
print(write)
df = pd.DataFrame(write)
df.to_excel("/Users/charliethebear/Documents/Lab/Entropy/Excel/patient_reactive2.xlsx")
# Out:
#     inactive active  inactive_entropy  active_entropy
# 0        206    NaN          6.405169             NaN
# 1       1062    NaN          7.184856             NaN
# 2        903    NaN          6.795668             NaN
# 3       1051    NaN          6.364052             NaN
# 4         34    NaN          6.837878             NaN
# ..       ...    ...               ...             ...
# 127      NaN    980               NaN        6.803508
# 128      NaN   1066               NaN        7.018536
# 129      NaN   1273               NaN        7.185106
# 130      NaN    905               NaN        6.993682
# 131      NaN   1424               NaN        7.091907
#
# [132 rows x 4 columns]

# %%
#圖片equalize和clahe後算entropy
num=0

#inactive
for f in files:
    #取得檔案路徑/病患編號
    if f[-3:]=="jpg":
        fullpath = join(mypath, f)
        number= f.split("_")[0]
        #print(number)
        
        img = cv2.imread(fullpath)
        colorIm=Image.open(fullpath)
        # convert the image into grayscale before doing histogram equalization
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # image equalization
        equalize_img = cv2.equalizeHist(gray_img)
        equalize_img= Image.fromarray(equalize_img)

        # create clahe image
        clahe_img = clahe.apply(gray_img)
        clahe_img = Image.fromarray(clahe_img)
        
        #算equalized image entropy
        greyIm_equ=equalize_img.convert('L')
        greyIm_equ=np.array(greyIm_equ)
        fullimg_equ= greyIm_equ[0:-1, 0:-1].flatten()
        ent_equ= entropy(fullimg_equ)
        
        #算clahe image entropy
        greyIm_clahe=clahe_img.convert('L')
        greyIm_clahe=np.array(greyIm_clahe)
        fullimg_clahe= greyIm_clahe[0:-1, 0:-1].flatten()
        ent_clahe= entropy(fullimg_clahe)
        
        writeclahe = writeclahe.append({
            "inactive": number,
            "equalized_inactive_entropy": ent_equ,
            "clahe_inactive_entropy": ent_clahe
        }, ignore_index=True)
    
    
    
#active
for f in files2:
    #取得檔案路徑/病患編號
    if f[-3:]=="jpg":
        fullpath = join(mypath2, f)
        number= f.split("_")[0]
        #print(number)
        
        img = cv2.imread(fullpath)
        colorIm=Image.open(fullpath)
        # convert the image into grayscale before doing histogram equalization
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # image equalization
        equalize_img = cv2.equalizeHist(gray_img)
        equalize_img= Image.fromarray(equalize_img)

        # create clahe image
        clahe_img = clahe.apply(gray_img)
        clahe_img = Image.fromarray(clahe_img)
        
        #算equalized image entropy
        greyIm_equ=equalize_img.convert('L')
        greyIm_equ=np.array(greyIm_equ)
        fullimg_equ= greyIm_equ[0:-1, 0:-1].flatten()
        ent_equ= entropy(fullimg_equ)
        
        #算clahe image entropy
        greyIm_clahe=clahe_img.convert('L')
        greyIm_clahe=np.array(greyIm_clahe)
        fullimg_clahe= greyIm_clahe[0:-1, 0:-1].flatten()
        ent_clahe= entropy(fullimg_clahe)
        
        writeclahe = writeclahe.append({
            "active": number,
            "equalized_active_entropy": ent_equ,
            "clahe_active_entropy": ent_clahe
        }, ignore_index=True)
    
    
print(writeclahe)
df2 = pd.DataFrame(writeclahe)
df2.to_excel("/Users/charliethebear/Documents/Lab/Entropy/Excel/patient_reactive_equalized.xlsx")
# Out:
#     inactive active  equalized_inactive_entropy  equalized_active_entropy  \
# 0        206    NaN                    6.189094                       NaN
# 1       1062    NaN                    6.961321                       NaN
# 2        903    NaN                    6.535566                       NaN
# 3       1051    NaN                    6.155108                       NaN
# 4         34    NaN                    6.605192                       NaN
# ..       ...    ...                         ...                       ...
# 523      NaN    980                         NaN                  6.572503
# 524      NaN   1066                         NaN                  6.797155
# 525      NaN   1273                         NaN                  6.962274
# 526      NaN    905                         NaN                  6.761225
# 527      NaN   1424                         NaN                  6.852685
#
#      clahe_inactive_entropy  clahe_active_entropy
# 0                  7.992987                   NaN
# 1                  7.993980                   NaN
# 2                  7.992709                   NaN
# 3                  7.991149                   NaN
# 4                  7.993039                   NaN
# ..                      ...                   ...
# 523                     NaN              7.991894
# 524                     NaN              7.989753
# 525                     NaN              7.991448
# 526                     NaN              7.992523
# 527                     NaN              7.992446
#
# [528 rows x 6 columns]

# %%
/Users/charliethebear/Documents/Lab/Entropy/Excel/patient_reactive.xlsx
