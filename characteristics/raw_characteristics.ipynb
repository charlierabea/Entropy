# %%
import os
import numpy as np
import pandas as pd
from skimage import io
import util2
import cv2
import tortuosity


parent_dir = r"/home/charlie/projects/entropy/input/"


# Create dictionaries to store the results
#active_stats: list[tuple[tuple, float]]
#inactive_stats: list[tuple[tuple, float]]

faz_area = {}
faz_circularity = {}
vessel_density = {}
vessel_length_density = {}


#第一層 列出前處理方式種類
for dirname in os.listdir(parent_dir):
    if (dirname.endswith(".DS_Store")):
        pass
    
    if(dirname == 'binary' or 'binary2'):
        pass
    #each image has up to two parameters, use 'parameter' list to store them
    parameter = []
    
    #each image has up to two parameters, use four lists to store the metrics
    reactive_active1 = []
    reactive_inactive1 = []
    treatment_active1 = []
    treatment_inactive1 = []
    
    reactive_active2 = []
    reactive_inactive2 = []
    treatment_active2 = []
    treatment_inactive2 = []
       
    type_dir = parent_dir + dirname+'/'
    print(type_dir)
    
    #第二層 列出前處理方式
    for dirname1 in os.listdir(type_dir):
        if (dirname1.endswith(".DS_Store")):
            continue
        
        pre_dir = type_dir + dirname1+'/'
        print(pre_dir)
        
        #第三層 列出reactive/treatment
        for dirname2 in os.listdir(pre_dir):
            if (dirname2.endswith(".DS_Store")):
                continue
            
            cond_dir = pre_dir + dirname2+'/'
            print(cond_dir)
            
            #第四層 列出active/inactive
            for dirname3 in os.listdir(cond_dir):
                if (dirname3.endswith(".DS_Store")):
                    continue
                    
                amd_dir = cond_dir + dirname3+'/'
                print(amd_dir)

                #列出目錄中的所有圖像
                for filename in os.listdir(amd_dir):
                    if not (filename.endswith(".bmp") or filename.endswith(".jpg")):
                        continue
                        
                    # 組合文件路徑
                    filepath = os.path.join(amd_dir, filename)
                    image = cv2.imread(filepath)
                    #print(filepath)
                    
                    #column名稱
                    column_name = dirname1+ '_'+ dirname2 + '_' + dirname3
                        
                    #initialize the parameters
                    img_parameter_1 = 0
                    img_parameter_2 = 0
                    image_name = filename.split('_')
                    
                    '''done'''
                    # if(dirname == 'faz'):
                    #     image = cv2.imread(filepath, cv2.COLOR_BGR2GRAY)
                    #     # calculate the blood vessel tortuosity
                    #     area, circularity = util2.calculate_faz_ci(image)
                    #     img_parameter_1 = area
                    #     # calculate the blood vessel caliber
                    #     img_parameter_2 = circularity
                    #     if(len(parameter)<3):
                    #         parameter.append("fazarea")
                    #         parameter.append('fazcirc') 
                    
                    
                    #分類：binary，parameter為entropy和VD
                    if(dirname == 'binary'):
                        # Read the image and calculate the entropy
                        img_parameter_1 = util2.calculate_image_entropy(filepath)
                        # Calculate the blood vessel density
                        img_parameter_2 = util2.calculate_bvd(filepath)
                        if(len(parameter)<3):
                            parameter.append("entropy")
                            parameter.append('vd')
                    
                    # if(dirname == 'skeletonize'):
                    #     print(image.shape)
                    #     # calculate the blood vessel tortuosity
                    #     img_parameter_1 = tortuosity.calculate_bvt_from_image(image, 128)
                    #     # calculate the fractal dimension
                    #     img_parameter_2 = util2.calculate_fd(image)
                    #     if(len(parameter)<3):
                    #         parameter.append("tortuosity")
                    #         parameter.append('fd')
                    
                    """not done"""
                    # #fd img_parameter_2 = util2.calculate_vpi(image)
                    # if(dirname == 'binary3'):
                    #     # calculate the blood vessel tortuosity
                    #     img_parameter_1 = util2.calculate_bvc(image)
                    #     # calculate the blood vessel fractal dimension
                    #     img_parameter_2 = util2.calculate_fd(image)
                        
                    #     if(len(parameter)<3):
                    #         parameter.append("caliber")
                    #         parameter.append('fd')
                    
                    # if(dirname == 'canny' or 'gabor' or 'raw'):
                    #     # Read the image and calculate the entropy
                    #     img_parameter_1 = util2.calculate_image_entropy(filepath)
                    #     img_parameter_2 = util2.calculate_image_entropy(filepath)
                    #     if(len(parameter)<3):                         
                    #         parameter.append("entropy")
                    #         parameter.append('entropy')   
                            
                    # Add the results to the dictionary
                    #entropy[(column_name, image_name[0], image.shape[0], image.shape[1])] = img_entropy
                    if dirname2 == 'reactive':
                        if dirname3 == 'active':
                            reactive_active1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            reactive_active2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                        if dirname3 == 'inactive':
                            reactive_inactive1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1)) 
                            reactive_inactive2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                            
                    if dirname2 == 'treatment':
                        if dirname3 == 'active':
                            treatment_active1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            treatment_active2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                        if dirname3 == 'inactive':
                            treatment_inactive1.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_1))
                            treatment_inactive2.append(((image_name[0], image.shape[0], image.shape[1], column_name), img_parameter_2))
                            
    # After reading all data, sort them by patient_number
    #先用方法分再用數字分
    n=0
    for a, b, c, d in ((reactive_active1, reactive_inactive1, treatment_active1, treatment_inactive1),(reactive_active2, reactive_inactive2, treatment_active2, treatment_inactive2)):
        for k in a,b,c,d:
            k.sort(key = lambda x: x[0][3])
            k.sort(key = lambda x: int(x[0][0]))

        dict_name_reactive = {}
        dict_name_treatment = {}
        
        #pair the active and inactive keys
        for (active_key, active_value), (inactive_key, inactive_value) in zip(a, b):
            pass
            dict_name_reactive[(inactive_key[0], inactive_key[3], active_key[0], active_key[3])] = [inactive_value, active_value]
        
        for (active_key, active_value), (inactive_key, inactive_value) in zip(c, d):
            pass
            dict_name_treatment[(active_key[0], active_key[3], inactive_key[0], inactive_key[3])] = [active_value, inactive_value]
            
        #print(dict_name_reactive)
        #print(dict_name_treatment)
            
        # Convert the results dictionary to a DataFrame with a multi-level index
        df_reactive = pd.DataFrame.from_dict(dict_name_reactive, orient='index')
        df_reactive.index = pd.MultiIndex.from_tuples(df_reactive.index, names=['inactive_number', 'inactive_process', 'active_number', 'active_process'])
        df_treatment = pd.DataFrame.from_dict(dict_name_treatment, orient='index')
        df_treatment.index = pd.MultiIndex.from_tuples(df_treatment.index, names=['active_number', 'active_process', 'inactive_number', 'inactive_process'])
        
        # Pivot the DataFrame to have directory names as columns
        df_reactive_inactive = df_reactive.pivot_table(values=0, index=['active_number','inactive_number'], columns=['inactive_process'])
        df_reactive_active = df_reactive.pivot_table(values=1, index=['active_number','inactive_number'], columns=['active_process'])
        df_treatment_active = df_treatment.pivot_table(values=0, index=['active_number','inactive_number'], columns=['active_process'])
        df_treatment_inactive = df_treatment.pivot_table(values=1, index=['active_number','inactive_number'], columns=['inactive_process'])
        
        # combine the two data frames using concat
        combined_df1 = pd.concat([df_reactive_inactive, df_reactive_active], axis = 1, ignore_index=False)
        combined_df2 = pd.concat([df_treatment_inactive, df_treatment_active], axis = 1, ignore_index=False)
        
        # Save the results to an Excel file
        excel_name1 = dirname + '_' + parameter[n] + '_reactive'
        excel_name2 = dirname + '_' + parameter[n] + '_treatment'
        combined_df1.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name1+ '.xlsx')
        combined_df2.to_excel('/home/charlie/projects/entropy/excel/'+ excel_name2+ '.xlsx')
        
        #計次   
        n+=1
# Out:
# /home/charlie/projects/entropy/input/binary/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/active/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/active/
# /home/charlie/projects/entropy/input/binary/gabor_otsu/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/otsu/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/active/
# /home/charlie/projects/entropy/input/binary/otsu/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/active/
# /home/charlie/projects/entropy/input/binary/otsu/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/mean/
# /home/charlie/projects/entropy/input/binary/mean/treatment/
# /home/charlie/projects/entropy/input/binary/mean/treatment/active/
# /home/charlie/projects/entropy/input/binary/mean/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/mean/reactive/
# /home/charlie/projects/entropy/input/binary/mean/reactive/active/
# /home/charlie/projects/entropy/input/binary/mean/reactive/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/active/
# /home/charlie/projects/entropy/input/binary/gabor_mean/treatment/inactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/active/
# /home/charlie/projects/entropy/input/binary/gabor_mean/reactive/inactive/
# {('2', 'gabor_mean_treatment_active', '3', 'gabor_mean_treatment_inactive'): [1.3492266494795897, 1.3869529859059069], ('2', 'gabor_otsu_treatment_active', '3', 'gabor_otsu_treatment_inactive'): [0.5535527607811341, 0.3796345309393381], ('2', 'mean_treatment_active', '3', 'mean_treatment_inactive'): [1.3197869866060028, 1.3702729213799858], ('2', 'otsu_treatment_active', '3', 'otsu_treatment_inactive'): [1.1138824235006748, 0.8196720556346813], ('18', 'gabor_mean_treatment_active', '23', 'gabor_mean_treatment_inactive'): [1.3226881900317338, 1.6164544425314256], ('18', 'gabor_otsu_treatment_active', '23', 'gabor_otsu_treatment_inactive'): [0.19092448730613298, 1.3219808412770873], ('18', 'mean_treatment_active', '23', 'mean_treatment_inactive'): [1.31421638400129, 1.7015683261752046], ('18', 'otsu_treatment_active', '23', 'otsu_treatment_inactive'): [1.3251589471584997, 1.4201633239940559], ('35', 'gabor_mean_treatment_active', '36', 'gabor_mean_treatment_inactive'): [1.5208999104104959, 1.5611413171246338], ('35', 'gabor_otsu_treatment_active', '36', 'gabor_otsu_treatment_inactive'): [1.308541797616725, 1.4486691315999356], ('35', 'mean_treatment_active', '36', 'mean_treatment_inactive'): [1.5579085600998075, 1.585236796393441], ('35', 'otsu_treatment_active', '36', 'otsu_treatment_inactive'): [1.3762785198445382, 1.4845985362858094], ('57', 'gabor_mean_treatment_active', '58', 'gabor_mean_treatment_inactive'): [1.5658186497917228, 1.704067780272736], ('57', 'gabor_otsu_treatment_active', '58', 'gabor_otsu_treatment_inactive'): [1.1521532936803394, 1.5341770340846246], ('57', 'mean_treatment_active', '58', 'mean_treatment_inactive'): [1.6435413041828915, 1.7894100148182512], ('57', 'otsu_treatment_active', '58', 'otsu_treatment_inactive'): [1.249584955669123, 1.5850651591640639], ('73', 'gabor_mean_treatment_active', '74', 'gabor_mean_treatment_inactive'): [1.7234332183391685, 1.5413777259740902], ('73', 'gabor_otsu_treatment_active', '74', 'gabor_otsu_treatment_inactive'): [1.4584116783232843, 1.0134275070909304], ('73', 'mean_treatment_active', '74', 'mean_treatment_inactive'): [1.7953944676151705, 1.6204104674299105], ('73', 'otsu_treatment_active', '74', 'otsu_treatment_inactive'): [1.4783917542265148, 1.1894407272484022], ('81', 'gabor_mean_treatment_active', '82', 'gabor_mean_treatment_inactive'): [1.3120595633507586, 1.5894337111976127], ('81', 'gabor_otsu_treatment_active', '82', 'gabor_otsu_treatment_inactive'): [0.6279366809757968, 1.391088931530146], ('81', 'mean_treatment_active', '82', 'mean_treatment_inactive'): [1.312406655234849, 1.6420738111740132], ('81', 'otsu_treatment_active', '82', 'otsu_treatment_inactive'): [0.7384891002670896, 1.3860677317997543], ('93', 'gabor_mean_treatment_active', '95', 'gabor_mean_treatment_inactive'): [1.7218946698738304, 1.7575933837524174], ('93', 'gabor_otsu_treatment_active', '95', 'gabor_otsu_treatment_inactive'): [1.6452725873594507, 1.405467721903042], ('93', 'mean_treatment_active', '95', 'mean_treatment_inactive'): [1.7412249988217596, 1.8064897717876267], ('93', 'otsu_treatment_active', '95', 'otsu_treatment_inactive'): [1.6700770388374053, 1.4613284036270344], ('104', 'gabor_mean_treatment_active', '107', 'gabor_mean_treatment_inactive'): [1.3938112463856722, 1.464194938464385], ('104', 'gabor_otsu_treatment_active', '107', 'gabor_otsu_treatment_inactive'): [0.5873140107476006, 1.4464676215172887], ('104', 'mean_treatment_active', '107', 'mean_treatment_inactive'): [1.3699325998789733, 1.5068444638377674], ('104', 'otsu_treatment_active', '107', 'otsu_treatment_inactive'): [0.9463320391657399, 1.4929712136683555], ('106', 'gabor_mean_treatment_active', '108', 'gabor_mean_treatment_inactive'): [1.4865769033555212, 1.4425059471499886], ('106', 'gabor_otsu_treatment_active', '108', 'gabor_otsu_treatment_inactive'): [0.9525283842433541, 0.9965191023490171], ('106', 'mean_treatment_active', '108', 'mean_treatment_inactive'): [1.4775863660913966, 1.4434915403910074], ('106' ...
# {('2', 'gabor_mean_treatment_active', '3', 'gabor_mean_treatment_inactive'): [0.14830780886608716, 0.15700233663157168], ('2', 'gabor_otsu_treatment_active', '3', 'gabor_otsu_treatment_inactive'): [0.03789969057388618, 0.02438620167152023], ('2', 'mean_treatment_active', '3', 'mean_treatment_inactive'): [0.14330308278742115, 0.15382065669728145], ('2', 'otsu_treatment_active', '3', 'otsu_treatment_inactive'): [0.09838621259886975, 0.06510879087056372], ('18', 'gabor_mean_treatment_active', '23', 'gabor_mean_treatment_inactive'): [0.14719139799046044, 0.19390581717451524], ('18', 'gabor_otsu_treatment_active', '23', 'gabor_otsu_treatment_inactive'): [0.01152106884048073, 0.13487809631001618], ('18', 'mean_treatment_active', '23', 'mean_treatment_inactive'): [0.14533010612277605, 0.21864715770532944], ('18', 'otsu_treatment_active', '23', 'otsu_treatment_inactive'): [0.12551700022401066, 0.1547695148803182], ('35', 'gabor_mean_treatment_active', '36', 'gabor_mean_treatment_inactive'): [0.1771141234171279, 0.18282002108978457], ('35', 'gabor_otsu_treatment_active', '36', 'gabor_otsu_treatment_inactive'): [0.13071113369430012, 0.1476849499436331], ('35', 'mean_treatment_active', '36', 'mean_treatment_inactive'): [0.18608547737036976, 0.1905584057725545], ('35', 'otsu_treatment_active', '36', 'otsu_treatment_inactive'): [0.14635363452751052, 0.15937721392654272], ('57', 'gabor_mean_treatment_active', '58', 'gabor_mean_treatment_inactive'): [0.1885732706103471, 0.20730821135679436], ('57', 'gabor_otsu_treatment_active', '58', 'gabor_otsu_treatment_inactive'): [0.1202573026566208, 0.16726129660286915], ('57', 'mean_treatment_active', '58', 'mean_treatment_inactive'): [0.21156259276864434, 0.23185468082122673], ('57', 'otsu_treatment_active', '58', 'otsu_treatment_inactive'): [0.1398609676896487, 0.18150327547301764], ('73', 'gabor_mean_treatment_active', '74', 'gabor_mean_treatment_inactive'): [0.21894765981703976, 0.17230426840484372], ('73', 'gabor_otsu_treatment_active', '74', 'gabor_otsu_treatment_inactive'): [0.16483360378523387, 0.09019434291115519], ('73', 'mean_treatment_active', '74', 'mean_treatment_inactive'): [0.24342128028469387, 0.1935561419899796], ('73', 'otsu_treatment_active', '74', 'otsu_treatment_inactive'): [0.17310196491956562, 0.11481730382220474], ('81', 'gabor_mean_treatment_active', '82', 'gabor_mean_treatment_inactive'): [0.14526454202567562, 0.19312451168406847], ('81', 'gabor_otsu_treatment_active', '82', 'gabor_otsu_treatment_inactive'): [0.05075207483048949, 0.14736259313288932], ('81', 'mean_treatment_active', '82', 'mean_treatment_inactive'): [0.1474718666280567, 0.20394805138039743], ('81', 'otsu_treatment_active', '82', 'otsu_treatment_inactive'): [0.0656770130454341, 0.15275888256923842], ('93', 'gabor_mean_treatment_active', '95', 'gabor_mean_treatment_inactive'): [0.21387736964127332, 0.22688637924094987], ('93', 'gabor_otsu_treatment_active', '95', 'gabor_otsu_treatment_inactive'): [0.1781941097943655, 0.15444533684465497], ('93', 'mean_treatment_active', '95', 'mean_treatment_inactive'): [0.21872182792702716, 0.24651372019793072], ('93', 'otsu_treatment_active', '95', 'otsu_treatment_inactive'): [0.19002296564623433, 0.1692446105401571], ('104', 'gabor_mean_treatment_active', '107', 'gabor_mean_treatment_inactive'): [0.15319051287514956, 0.15997457570012438], ('104', 'gabor_otsu_treatment_active', '107', 'gabor_otsu_treatment_inactive'): [0.04062242182847339, 0.1450113917618712], ('104', 'mean_treatment_active', '107', 'mean_treatment_inactive'): [0.1476849499436331, 0.17078536682201714], ('104', 'otsu_treatment_active', '107', 'otsu_treatment_inactive'): [0.08003190786058888, 0.1582134512030101], ('106', 'gabor_mean_treatment_active', '108', 'gabor_mean_treatment_inactive'): [0.16244779914074609, 0.1616755997748966], ('106', 'gabor_otsu_treatment_active', '108', 'gabor_otsu_treatment_inactive'): [0.08239221535620428, 0.0870745846241265], ('106', 'mean_treatment_active', '108', 'mean_treatment_ ...

# %%
print(treatment_active2)
# Out:
# [(('2', 741, 741, 'gabor_mean_treatment_active'), 0.14830780886608716), (('2', 741, 741, 'gabor_otsu_treatment_active'), 0.03789969057388618), (('2', 741, 741, 'mean_treatment_active'), 0.14330308278742115), (('2', 741, 741, 'otsu_treatment_active'), 0.09838621259886975), (('18', 741, 741, 'gabor_mean_treatment_active'), 0.14719139799046044), (('18', 741, 741, 'gabor_otsu_treatment_active'), 0.01152106884048073), (('18', 741, 741, 'mean_treatment_active'), 0.14533010612277605), (('18', 741, 741, 'otsu_treatment_active'), 0.12551700022401066), (('35', 741, 741, 'gabor_mean_treatment_active'), 0.1771141234171279), (('35', 741, 741, 'gabor_otsu_treatment_active'), 0.13071113369430012), (('35', 741, 741, 'mean_treatment_active'), 0.18608547737036976), (('35', 741, 741, 'otsu_treatment_active'), 0.14635363452751052), (('57', 741, 741, 'gabor_mean_treatment_active'), 0.1885732706103471), (('57', 741, 741, 'gabor_otsu_treatment_active'), 0.1202573026566208), (('57', 741, 741, 'mean_treatment_active'), 0.21156259276864434), (('57', 741, 741, 'otsu_treatment_active'), 0.1398609676896487), (('73', 741, 741, 'gabor_mean_treatment_active'), 0.21894765981703976), (('73', 741, 741, 'gabor_otsu_treatment_active'), 0.16483360378523387), (('73', 741, 741, 'mean_treatment_active'), 0.24342128028469387), (('73', 741, 741, 'otsu_treatment_active'), 0.17310196491956562), (('81', 741, 741, 'gabor_mean_treatment_active'), 0.14526454202567562), (('81', 741, 741, 'gabor_otsu_treatment_active'), 0.05075207483048949), (('81', 741, 741, 'mean_treatment_active'), 0.1474718666280567), (('81', 741, 741, 'otsu_treatment_active'), 0.0656770130454341), (('93', 741, 741, 'gabor_mean_treatment_active'), 0.21387736964127332), (('93', 741, 741, 'gabor_otsu_treatment_active'), 0.1781941097943655), (('93', 741, 741, 'mean_treatment_active'), 0.21872182792702716), (('93', 741, 741, 'otsu_treatment_active'), 0.19002296564623433), (('104', 741, 741, 'gabor_mean_treatment_active'), 0.15319051287514956), (('104', 741, 741, 'gabor_otsu_treatment_active'), 0.04062242182847339), (('104', 741, 741, 'mean_treatment_active'), 0.1476849499436331), (('104', 741, 741, 'otsu_treatment_active'), 0.08003190786058888), (('106', 741, 741, 'gabor_mean_treatment_active'), 0.16244779914074609), (('106', 741, 741, 'gabor_otsu_treatment_active'), 0.08239221535620428), (('106', 741, 741, 'mean_treatment_active'), 0.1627391951278591), (('106', 741, 741, 'otsu_treatment_active'), 0.09623352474407237), (('110', 741, 741, 'gabor_mean_treatment_active'), 0.19574889679300503), (('110', 741, 741, 'gabor_otsu_treatment_active'), 0.21283927143718323), (('110', 741, 741, 'mean_treatment_active'), 0.20483680914109212), (('110', 741, 741, 'otsu_treatment_active'), 0.2123184011102187), (('133', 741, 741, 'gabor_mean_treatment_active'), 0.16087426081033582), (('133', 741, 741, 'gabor_otsu_treatment_active'), 0.02324611487194057), (('133', 741, 741, 'mean_treatment_active'), 0.15506273209235066), (('133', 741, 741, 'otsu_treatment_active'), 0.04969030070244645), (('138', 741, 741, 'gabor_mean_treatment_active'), 0.22882598378017086), (('138', 741, 741, 'gabor_otsu_treatment_active'), 0.20834995201072337), (('138', 741, 741, 'mean_treatment_active'), 0.24760827637452398), (('138', 741, 741, 'otsu_treatment_active'), 0.21584065010444725), (('155', 741, 741, 'gabor_mean_treatment_active'), 0.14890517063966882), (('155', 741, 741, 'gabor_otsu_treatment_active'), 0.05409948623245022), (('155', 741, 741, 'mean_treatment_active'), 0.14771226831742493), (('155', 741, 741, 'otsu_treatment_active'), 0.06760933268497726), (('163', 741, 741, 'gabor_mean_treatment_active'), 0.1998666863358958), (('163', 741, 741, 'gabor_otsu_treatment_active'), 0.1334557196479208), (('163', 741, 741, 'mean_treatment_active'), 0.22112948727054843), (('163', 741, 741, 'otsu_treatment_active'), 0.13879919356160567), (('175', 741, 741, 'gabor_mean_treatment_active'), 0.2059932869649469), (('175', 741, 741, 'gabor_otsu_treatment_active'),  ...

# %%
import numpy as np
import cv2
from skimage.measure import regionprops, label
#from scipy.spatial import distance

path ='/home/charlie/projects/entropy/input/faz/faz/reactive/active/6_1054482-8_20170926_OCT_00000256.bmp_superficial.jpg'

faz_image = cv2.imread('/home/charlie/projects/entropy/input/faz/faz/reactive/active/6_1054482-8_20170926_OCT_00000256.bmp_superficial.jpg', cv2.COLOR_BGR2GRAY)

#faz_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Label the binary FAZ image and extract the properties of each connected component
labeled_image = label(faz_image)
regions = regionprops(labeled_image)
# Find the largest connected component (i.e., the FAZ)
faz_region = max(regions, key=lambda r: r.area)
# Calculate the perimeter of the FAZ
faz_perimeter = faz_region.perimeter
# Calculate the radius of a reference circle with area identical to the FAZ
faz_area = faz_region.filled_area
faz_radius = np.sqrt(faz_area / np.pi)
# Calculate the perimeter of the reference circle
reference_perimeter = 2 * np.pi * faz_radius
# Calculate the FAZ-CI as the ratio of the FAZ perimeter to the reference circle perimeter
faz_ci = faz_perimeter / reference_perimeter
print(faz_area, faz_ci)
# Out:
# 39460 4.0334067952621675
